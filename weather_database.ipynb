# %%
import pandas as pd
import numpy as np
from config import gmaps_api_key
from citipy import citipy
from config import weather_api_key
import time
from datetime import datetime
import requests

# %%
# create a random set of 2000 lats and lngs
lats = np.random.uniform(low=-90, high=90, size=2000)
lngs = np.random.uniform(low=-180, high=180, size=2000)

lats_lngs = list(zip(lats, lngs))

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in lats_lngs:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 746

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
url = 'http://api.openweathermap.org/data/2.5/weather?'

for i, city in enumerate(cities):
    
    if(i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)
        
    # Create endpoint URL with each city.
    city_url = url + 'appid='+ weather_api_key + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
       # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"] * 1.8 - 459.67
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        current_desc = city_weather["weather"][0]['description']
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max_Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current_Description": current_desc,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | bontang
# Processing Record 2 of Set 1 | bluff
# Processing Record 3 of Set 1 | riberalta
# Processing Record 4 of Set 1 | longyearbyen
# Processing Record 5 of Set 1 | esperance
# Processing Record 6 of Set 1 | yellowknife
# Processing Record 7 of Set 1 | new norfolk
# Processing Record 8 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 9 of Set 1 | paro
# Processing Record 10 of Set 1 | hobart
# Processing Record 11 of Set 1 | port macquarie
# Processing Record 12 of Set 1 | ruatoria
# City not found. Skipping...
# Processing Record 13 of Set 1 | puerto ayora
# Processing Record 14 of Set 1 | cabra
# Processing Record 15 of Set 1 | qaanaaq
# Processing Record 16 of Set 1 | toliary
# City not found. Skipping...
# Processing Record 17 of Set 1 | port blair
# Processing Record 18 of Set 1 | busselton
# Processing Record 19 of Set 1 | george town
# Processing Record 20 of Set 1 | ribeira grande
# Processing Record 21 of Set 1 | sept-iles
# Processing Record 22 of Set 1 | rikitea
# Processing Record 23 of Set 1 | norman wells
# Processing Record 24 of Set 1 | ushuaia
# Processing Record 25 of Set 1 | saldanha
# Processing Record 26 of Set 1 | kaitangata
# Processing Record 27 of Set 1 | killybegs
# Processing Record 28 of Set 1 | haines junction
# Processing Record 29 of Set 1 | imeni poliny osipenko
# Processing Record 30 of Set 1 | ballina
# Processing Record 31 of Set 1 | arraial do cabo
# Processing Record 32 of Set 1 | nanortalik
# Processing Record 33 of Set 1 | marsh harbour
# Processing Record 34 of Set 1 | isangel
# Processing Record 35 of Set 1 | strezhevoy
# Processing Record 36 of Set 1 | tasiilaq
# Processing Record 37 of Set 1 | bogo
# Processing Record 38 of Set 1 | klaksvik
# Processing Record 39 of Set 1 | jacareacanga
# Processing Record 40 of Set 1 | taoudenni
# Processing Record 41 of Set 1 | constantine
# Processing Record 42 of Set 1 | sitka
# Processing Record 43 of Set 1 | mount isa
# Processing Record 44 of Set 1 | cape town
# Processing Record 45 of Set 1 | butaritari
# Processing Record 46 of Set 1 | semirom
# Processing Record 47 of Set 1 | ilulissat
# Processing Record 48 of Set 1 | makat
# Processing Record 49 of Set 1 | tuktoyaktuk
# Processing Record 50 of Set 1 | ponta do sol
# Processing Record 1 of Set 2 | mar del plata
# Processing Record 2 of Set 2 | hermanus
# Processing Record 3 of Set 2 | itapaci
# Processing Record 4 of Set 2 | thompson
# Processing Record 5 of Set 2 | mataura
# Processing Record 6 of Set 2 | bandar-e torkaman
# City not found. Skipping...
# Processing Record 7 of Set 2 | port alfred
# Processing Record 8 of Set 2 | padang
# Processing Record 9 of Set 2 | berlevag
# Processing Record 10 of Set 2 | albany
# Processing Record 11 of Set 2 | clyde river
# Processing Record 12 of Set 2 | dikson
# Processing Record 13 of Set 2 | ambanja
# Processing Record 14 of Set 2 | airai
# Processing Record 15 of Set 2 | sambava
# Processing Record 16 of Set 2 | los llanos de aridane
# Processing Record 17 of Set 2 | punta arenas
# Processing Record 18 of Set 2 | te anau
# Processing Record 19 of Set 2 | vaini
# Processing Record 20 of Set 2 | kahului
# Processing Record 21 of Set 2 | watsa
# Processing Record 22 of Set 2 | portland
# Processing Record 23 of Set 2 | leningradskiy
# Processing Record 24 of Set 2 | tiksi
# Processing Record 25 of Set 2 | meiganga
# Processing Record 26 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 27 of Set 2 | narsaq
# Processing Record 28 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 29 of Set 2 | nuuk
# Processing Record 30 of Set 2 | plouzane
# Processing Record 31 of Set 2 | lebu
# Processing Record 32 of Set 2 | saint augustine
# Processing Record 33 of Set 2 | san cristobal
# Processing Record 34 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 35 of Set 2 | floro
# Processing Record 36 of Set 2 | uyuni
# Processing Record 37 of Set 2 | bredasdorp
# Processing Record 38 of Set 2 | borogontsy
# Processing Record 39 of Set 2 | port lincoln
# Processing Record 40 of Set 2 | outram
# Processing Record 41 of Set 2 | mago
# Processing Record 42 of Set 2 | rio grande
# Processing Record 43 of Set 2 | barrow
# Processing Record 44 of Set 2 | saint-augustin
# Processing Record 45 of Set 2 | lasa
# Processing Record 46 of Set 2 | bethel
# Processing Record 47 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 48 of Set 2 | taksimo
# Processing Record 49 of Set 2 | hofn
# Processing Record 50 of Set 2 | provideniya
# Processing Record 1 of Set 3 | sao felix do xingu
# Processing Record 2 of Set 3 | severo-kurilsk
# Processing Record 3 of Set 3 | oranjemund
# Processing Record 4 of Set 3 | manaure
# Processing Record 5 of Set 3 | hamina
# Processing Record 6 of Set 3 | atuona
# Processing Record 7 of Set 3 | kapaa
# Processing Record 8 of Set 3 | solovetskiy
# City not found. Skipping...
# Processing Record 9 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 10 of Set 3 | nago
# Processing Record 11 of Set 3 | vila franca do campo
# Processing Record 12 of Set 3 | roald
# Processing Record 13 of Set 3 | kavieng
# Processing Record 14 of Set 3 | upernavik
# Processing Record 15 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 16 of Set 3 | sao miguel do araguaia
# Processing Record 17 of Set 3 | port elizabeth
# Processing Record 18 of Set 3 | iqaluit
# Processing Record 19 of Set 3 | takoradi
# Processing Record 20 of Set 3 | port shepstone
# Processing Record 21 of Set 3 | cherskiy
# Processing Record 22 of Set 3 | kruisfontein
# Processing Record 23 of Set 3 | jamestown
# Processing Record 24 of Set 3 | ostrovnoy
# Processing Record 25 of Set 3 | naze
# Processing Record 26 of Set 3 | kirakira
# Processing Record 27 of Set 3 | cayenne
# Processing Record 28 of Set 3 | canutama
# Processing Record 29 of Set 3 | le port
# Processing Record 30 of Set 3 | jinchang
# Processing Record 31 of Set 3 | sao luiz gonzaga
# Processing Record 32 of Set 3 | rio cuarto
# Processing Record 33 of Set 3 | pemba
# Processing Record 34 of Set 3 | tiarei
# Processing Record 35 of Set 3 | groa
# Processing Record 36 of Set 3 | matara
# Processing Record 37 of Set 3 | gurupi
# Processing Record 38 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 39 of Set 3 | russkaya polyana
# Processing Record 40 of Set 3 | saint-philippe
# Processing Record 41 of Set 3 | anadyr
# Processing Record 42 of Set 3 | wasilla
# Processing Record 43 of Set 3 | bengkulu
# Processing Record 44 of Set 3 | barmer
# Processing Record 45 of Set 3 | kachiry
# Processing Record 46 of Set 3 | tutoia
# Processing Record 47 of Set 3 | dudinka
# Processing Record 48 of Set 3 | husavik
# Processing Record 49 of Set 3 | lavrentiya
# Processing Record 50 of Set 3 | petropavlovsk-kamchatskiy
# Processing Record 1 of Set 4 | kropotkin
# Processing Record 2 of Set 4 | primorsko
# Processing Record 3 of Set 4 | chuy
# Processing Record 4 of Set 4 | coahuayana
# Processing Record 5 of Set 4 | pierre
# Processing Record 6 of Set 4 | srednekolymsk
# Processing Record 7 of Set 4 | lompoc
# Processing Record 8 of Set 4 | poum
# Processing Record 9 of Set 4 | yuli
# Processing Record 10 of Set 4 | ambilobe
# Processing Record 11 of Set 4 | shiyan
# Processing Record 12 of Set 4 | manta
# Processing Record 13 of Set 4 | lorengau
# Processing Record 14 of Set 4 | malakisi
# City not found. Skipping...
# Processing Record 15 of Set 4 | nouadhibou
# Processing Record 16 of Set 4 | klatovy
# Processing Record 17 of Set 4 | zhanaozen
# Processing Record 18 of Set 4 | sjenica
# Processing Record 19 of Set 4 | codrington
# Processing Record 20 of Set 4 | vila velha
# Processing Record 21 of Set 4 | omboue
# Processing Record 22 of Set 4 | high level
# Processing Record 23 of Set 4 | calabozo
# Processing Record 24 of Set 4 | baykit
# Processing Record 25 of Set 4 | mount gambier
# Processing Record 26 of Set 4 | nikolskoye
# Processing Record 27 of Set 4 | college
# Processing Record 28 of Set 4 | mgandu
# Processing Record 29 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 30 of Set 4 | zhigansk
# Processing Record 31 of Set 4 | castro
# Processing Record 32 of Set 4 | bonthe
# Processing Record 33 of Set 4 | yeppoon
# Processing Record 34 of Set 4 | avarua
# Processing Record 35 of Set 4 | kaeo
# Processing Record 36 of Set 4 | berbera
# Processing Record 37 of Set 4 | ewo
# Processing Record 38 of Set 4 | taunggyi
# Processing Record 39 of Set 4 | vao
# Processing Record 40 of Set 4 | wagga wagga
# Processing Record 41 of Set 4 | ulaangom
# Processing Record 42 of Set 4 | guarapari
# Processing Record 43 of Set 4 | cidreira
# Processing Record 44 of Set 4 | kaseda
# Processing Record 45 of Set 4 | luanda
# Processing Record 46 of Set 4 | yusva
# City not found. Skipping...
# Processing Record 47 of Set 4 | altamira
# Processing Record 48 of Set 4 | turochak
# Processing Record 49 of Set 4 | mogadishu
# Processing Record 50 of Set 4 | dwarka
# Processing Record 1 of Set 5 | wanaka
# Processing Record 2 of Set 5 | lumby
# Processing Record 3 of Set 5 | gold coast
# Processing Record 4 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 5 of Set 5 | aklavik
# Processing Record 6 of Set 5 | hithadhoo
# Processing Record 7 of Set 5 | bolungarvik
# City not found. Skipping...
# Processing Record 8 of Set 5 | saint george
# Processing Record 9 of Set 5 | carnarvon
# Processing Record 10 of Set 5 | torbay
# Processing Record 11 of Set 5 | balkhash
# Processing Record 12 of Set 5 | mackay
# Processing Record 13 of Set 5 | batagay-alyta
# Processing Record 14 of Set 5 | chokurdakh
# Processing Record 15 of Set 5 | douentza
# Processing Record 16 of Set 5 | igarka
# Processing Record 17 of Set 5 | harper
# Processing Record 18 of Set 5 | katsuura
# Processing Record 19 of Set 5 | faya
# Processing Record 20 of Set 5 | tostamaa
# City not found. Skipping...
# Processing Record 21 of Set 5 | palmares do sul
# Processing Record 22 of Set 5 | hailar
# Processing Record 23 of Set 5 | svetlyy
# Processing Record 24 of Set 5 | mahebourg
# Processing Record 25 of Set 5 | khatanga
# Processing Record 26 of Set 5 | hilo
# Processing Record 27 of Set 5 | goderich
# Processing Record 28 of Set 5 | tepalcatepec
# Processing Record 29 of Set 5 | bathsheba
# Processing Record 30 of Set 5 | methoni
# Processing Record 31 of Set 5 | dalbandin
# Processing Record 32 of Set 5 | grindavik
# Processing Record 33 of Set 5 | opuwo
# Processing Record 34 of Set 5 | vrangel
# Processing Record 35 of Set 5 | litovko
# Processing Record 36 of Set 5 | biu
# Processing Record 37 of Set 5 | witu
# Processing Record 38 of Set 5 | margate
# Processing Record 39 of Set 5 | tomatlan
# Processing Record 40 of Set 5 | marawi
# Processing Record 41 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 42 of Set 5 | marsa matruh
# Processing Record 43 of Set 5 | tateyama
# Processing Record 44 of Set 5 | asau
# Processing Record 45 of Set 5 | krasnoselkup
# Processing Record 46 of Set 5 | colesberg
# Processing Record 47 of Set 5 | cockburn town
# Processing Record 48 of Set 5 | kidal
# Processing Record 49 of Set 5 | kodiak
# Processing Record 50 of Set 5 | talnakh
# Processing Record 1 of Set 6 | fairbanks
# City not found. Skipping...
# Processing Record 2 of Set 6 | ayagoz
# Processing Record 3 of Set 6 | mariental
# Processing Record 4 of Set 6 | san patricio
# Processing Record 5 of Set 6 | burriana
# Processing Record 6 of Set 6 | sovetskiy
# Processing Record 7 of Set 6 | luganville
# Processing Record 8 of Set 6 | tazovskiy
# Processing Record 9 of Set 6 | araceli
# Processing Record 10 of Set 6 | ancud
# Processing Record 11 of Set 6 | tyup
# Processing Record 12 of Set 6 | yeniseysk
# Processing Record 13 of Set 6 | hay river
# Processing Record 14 of Set 6 | east london
# Processing Record 15 of Set 6 | taltal
# Processing Record 16 of Set 6 | alice springs
# Processing Record 17 of Set 6 | mirzapur
# Processing Record 18 of Set 6 | tra vinh
# Processing Record 19 of Set 6 | zhitikara
# City not found. Skipping...
# Processing Record 20 of Set 6 | wanning
# Processing Record 21 of Set 6 | sinjah
# City not found. Skipping...
# Processing Record 22 of Set 6 | aswan
# Processing Record 23 of Set 6 | dauphin
# Processing Record 24 of Set 6 | belaya gora
# Processing Record 25 of Set 6 | itupiranga
# Processing Record 26 of Set 6 | grand gaube
# Processing Record 27 of Set 6 | kantunilkin
# Processing Record 28 of Set 6 | sun valley
# Processing Record 29 of Set 6 | georgetown
# Processing Record 30 of Set 6 | oktyabrskiy
# Processing Record 31 of Set 6 | talcahuano
# Processing Record 32 of Set 6 | fallon
# Processing Record 33 of Set 6 | laja
# Processing Record 34 of Set 6 | forest hills
# Processing Record 35 of Set 6 | moyo
# Processing Record 36 of Set 6 | xingyi
# Processing Record 37 of Set 6 | sisimiut
# Processing Record 38 of Set 6 | yulara
# Processing Record 39 of Set 6 | mizdah
# Processing Record 40 of Set 6 | shingu
# Processing Record 41 of Set 6 | price
# Processing Record 42 of Set 6 | olafsvik
# Processing Record 43 of Set 6 | lagoa
# Processing Record 44 of Set 6 | port keats
# Processing Record 45 of Set 6 | ouallam
# Processing Record 46 of Set 6 | saint anthony
# Processing Record 47 of Set 6 | farafangana
# Processing Record 48 of Set 6 | geraldton
# Processing Record 49 of Set 6 | valparai
# Processing Record 50 of Set 6 | hambantota
# Processing Record 1 of Set 7 | preobrazheniye
# Processing Record 2 of Set 7 | yuxia
# Processing Record 3 of Set 7 | caravelas
# Processing Record 4 of Set 7 | ashland
# Processing Record 5 of Set 7 | umtata
# Processing Record 6 of Set 7 | sampit
# Processing Record 7 of Set 7 | union city
# Processing Record 8 of Set 7 | dawei
# Processing Record 9 of Set 7 | zonguldak
# Processing Record 10 of Set 7 | bemidji
# Processing Record 11 of Set 7 | egvekinot
# Processing Record 12 of Set 7 | manzhouli
# Processing Record 13 of Set 7 | coolum beach
# Processing Record 14 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 15 of Set 7 | honningsvag
# Processing Record 16 of Set 7 | mayumba
# Processing Record 17 of Set 7 | popondetta
# Processing Record 18 of Set 7 | tongren
# Processing Record 19 of Set 7 | mahon
# Processing Record 20 of Set 7 | qingdao
# Processing Record 21 of Set 7 | makubetsu
# Processing Record 22 of Set 7 | santa cruz
# Processing Record 23 of Set 7 | galabovo
# Processing Record 24 of Set 7 | hasaki
# Processing Record 25 of Set 7 | cabo san lucas
# Processing Record 26 of Set 7 | shimoda
# Processing Record 27 of Set 7 | lolua
# City not found. Skipping...
# Processing Record 28 of Set 7 | pevek
# Processing Record 29 of Set 7 | miyako
# Processing Record 30 of Set 7 | tucuma
# Processing Record 31 of Set 7 | sao joao da barra
# Processing Record 32 of Set 7 | stepnyak
# Processing Record 33 of Set 7 | jasdan
# Processing Record 34 of Set 7 | abbotsford
# Processing Record 35 of Set 7 | hervey bay
# Processing Record 36 of Set 7 | urumqi
# Processing Record 37 of Set 7 | trinidad
# Processing Record 38 of Set 7 | qaqortoq
# Processing Record 39 of Set 7 | tabiauea
# City not found. Skipping...
# Processing Record 40 of Set 7 | berezovyy
# Processing Record 41 of Set 7 | alofi
# Processing Record 42 of Set 7 | turukhansk
# Processing Record 43 of Set 7 | malatya
# Processing Record 44 of Set 7 | hit
# Processing Record 45 of Set 7 | vardo
# Processing Record 46 of Set 7 | key largo
# Processing Record 47 of Set 7 | ngukurr
# City not found. Skipping...
# Processing Record 48 of Set 7 | tuatapere
# Processing Record 49 of Set 7 | candawaga
# City not found. Skipping...
# Processing Record 50 of Set 7 | louisbourg
# City not found. Skipping...
# Processing Record 1 of Set 8 | okhotsk
# Processing Record 2 of Set 8 | ponta delgada
# Processing Record 3 of Set 8 | faanui
# Processing Record 4 of Set 8 | owensboro
# Processing Record 5 of Set 8 | muli
# Processing Record 6 of Set 8 | eirunepe
# Processing Record 7 of Set 8 | maldonado
# Processing Record 8 of Set 8 | embrach
# Processing Record 9 of Set 8 | adrar
# Processing Record 10 of Set 8 | kanigoro
# Processing Record 11 of Set 8 | mokhsogollokh
# Processing Record 12 of Set 8 | janauba
# Processing Record 13 of Set 8 | mormugao
# Processing Record 14 of Set 8 | teknaf
# Processing Record 15 of Set 8 | khalkhal
# Processing Record 16 of Set 8 | zhaocheng
# City not found. Skipping...
# Processing Record 17 of Set 8 | zlobin
# Processing Record 18 of Set 8 | broken hill
# Processing Record 19 of Set 8 | segezha
# Processing Record 20 of Set 8 | lata
# Processing Record 21 of Set 8 | salalah
# Processing Record 22 of Set 8 | hualmay
# Processing Record 23 of Set 8 | kalmunai
# Processing Record 24 of Set 8 | stranda
# Processing Record 25 of Set 8 | constitucion
# Processing Record 26 of Set 8 | juazeiro
# Processing Record 27 of Set 8 | palmer
# Processing Record 28 of Set 8 | zhengjiatun
# Processing Record 29 of Set 8 | sumbawa
# City not found. Skipping...
# Processing Record 30 of Set 8 | sena madureira
# Processing Record 31 of Set 8 | santa maria
# Processing Record 32 of Set 8 | ampanihy
# Processing Record 33 of Set 8 | rafai
# Processing Record 34 of Set 8 | sterling
# Processing Record 35 of Set 8 | adwa
# Processing Record 36 of Set 8 | hovd
# Processing Record 37 of Set 8 | betki
# City not found. Skipping...
# Processing Record 38 of Set 8 | florence
# Processing Record 39 of Set 8 | novaya zaimka
# Processing Record 40 of Set 8 | ixtapa
# Processing Record 41 of Set 8 | saskylakh
# Processing Record 42 of Set 8 | tautira
# Processing Record 43 of Set 8 | rach gia
# Processing Record 44 of Set 8 | pacific grove
# Processing Record 45 of Set 8 | road town
# Processing Record 46 of Set 8 | jaciara
# Processing Record 47 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 48 of Set 8 | kambove
# Processing Record 49 of Set 8 | angoche
# Processing Record 50 of Set 8 | grand centre
# City not found. Skipping...
# Processing Record 1 of Set 9 | lalganj
# Processing Record 2 of Set 9 | rocha
# Processing Record 3 of Set 9 | onda
# Processing Record 4 of Set 9 | sola
# Processing Record 5 of Set 9 | thunder bay
# Processing Record 6 of Set 9 | destin
# Processing Record 7 of Set 9 | fortuna
# Processing Record 8 of Set 9 | jabiru
# City not found. Skipping...
# Processing Record 9 of Set 9 | carutapera
# Processing Record 10 of Set 9 | nhulunbuy
# Processing Record 11 of Set 9 | shitanjing
# Processing Record 12 of Set 9 | strenci
# Processing Record 13 of Set 9 | rafraf
# Processing Record 14 of Set 9 | batala
# Processing Record 15 of Set 9 | yerbogachen
# Processing Record 16 of Set 9 | fukue
# Processing Record 17 of Set 9 | samusu
# City not found. Skipping...
# Processing Record 18 of Set 9 | redwater
# Processing Record 19 of Set 9 | auriflama
# Processing Record 20 of Set 9 | kemijarvi
# Processing Record 21 of Set 9 | grimari
# City not found. Skipping...
# Processing Record 22 of Set 9 | aguimes
# Processing Record 23 of Set 9 | katol
# Processing Record 24 of Set 9 | aflu
# City not found. Skipping...
# Processing Record 25 of Set 9 | dryden
# Processing Record 26 of Set 9 | pelym
# Processing Record 27 of Set 9 | warri
# Processing Record 28 of Set 9 | saint-joseph
# Processing Record 29 of Set 9 | almaznyy
# Processing Record 30 of Set 9 | zyryanka
# Processing Record 31 of Set 9 | calama
# Processing Record 32 of Set 9 | yazykovo
# Processing Record 33 of Set 9 | saleaula
# City not found. Skipping...
# Processing Record 34 of Set 9 | paamiut
# Processing Record 35 of Set 9 | victoria
# Processing Record 36 of Set 9 | karanja
# Processing Record 37 of Set 9 | avera
# Processing Record 38 of Set 9 | gazimurskiy zavod
# Processing Record 39 of Set 9 | charters towers
# Processing Record 40 of Set 9 | nishihara
# Processing Record 41 of Set 9 | belmonte
# Processing Record 42 of Set 9 | owosso
# Processing Record 43 of Set 9 | khorramshahr
# Processing Record 44 of Set 9 | wendo
# Processing Record 45 of Set 9 | nizwa
# Processing Record 46 of Set 9 | half moon bay
# Processing Record 47 of Set 9 | pozo colorado
# Processing Record 48 of Set 9 | bayji
# Processing Record 49 of Set 9 | lamar
# Processing Record 50 of Set 9 | cacoal
# Processing Record 1 of Set 10 | bac lieu
# Processing Record 2 of Set 10 | pochutla
# Processing Record 3 of Set 10 | palabuhanratu
# City not found. Skipping...
# Processing Record 4 of Set 10 | cabedelo
# Processing Record 5 of Set 10 | vapi
# Processing Record 6 of Set 10 | sibu
# Processing Record 7 of Set 10 | terrace
# Processing Record 8 of Set 10 | karaton
# Processing Record 9 of Set 10 | champasak
# Processing Record 10 of Set 10 | inongo
# Processing Record 11 of Set 10 | coquimbo
# Processing Record 12 of Set 10 | henties bay
# Processing Record 13 of Set 10 | tidore
# City not found. Skipping...
# Processing Record 14 of Set 10 | toul
# Processing Record 15 of Set 10 | santa isabel do rio negro
# Processing Record 16 of Set 10 | bacolod
# Processing Record 17 of Set 10 | pitkyaranta
# Processing Record 18 of Set 10 | alpena
# Processing Record 19 of Set 10 | verkhoyansk
# Processing Record 20 of Set 10 | tahta
# Processing Record 21 of Set 10 | san ignacio
# Processing Record 22 of Set 10 | buraydah
# Processing Record 23 of Set 10 | caucaia
# Processing Record 24 of Set 10 | stykkisholmur
# Processing Record 25 of Set 10 | honiara
# Processing Record 26 of Set 10 | sivas
# Processing Record 27 of Set 10 | khandyga
# Processing Record 28 of Set 10 | turan
# Processing Record 29 of Set 10 | mwinilunga
# Processing Record 30 of Set 10 | necochea
# Processing Record 31 of Set 10 | ruteng
# Processing Record 32 of Set 10 | ambon
# Processing Record 33 of Set 10 | krasnoborsk
# Processing Record 34 of Set 10 | rena
# Processing Record 35 of Set 10 | taloqan
# Processing Record 36 of Set 10 | lanxi
# Processing Record 37 of Set 10 | hearst
# Processing Record 38 of Set 10 | maua
# Processing Record 39 of Set 10 | le pradet
# Processing Record 40 of Set 10 | namibe
# Processing Record 41 of Set 10 | rawson
# Processing Record 42 of Set 10 | bahia blanca
# Processing Record 43 of Set 10 | caraquet
# Processing Record 44 of Set 10 | deputatskiy
# Processing Record 45 of Set 10 | pasighat
# Processing Record 46 of Set 10 | chimbote
# Processing Record 47 of Set 10 | svobodnyy
# Processing Record 48 of Set 10 | bacuit
# City not found. Skipping...
# Processing Record 49 of Set 10 | ajdabiya
# Processing Record 50 of Set 10 | koscian
# Processing Record 1 of Set 11 | riyadh
# Processing Record 2 of Set 11 | achisay
# City not found. Skipping...
# Processing Record 3 of Set 11 | san policarpo
# Processing Record 4 of Set 11 | bilma
# Processing Record 5 of Set 11 | hemnesberget
# Processing Record 6 of Set 11 | sibolga
# Processing Record 7 of Set 11 | san quintin
# Processing Record 8 of Set 11 | emerald
# Processing Record 9 of Set 11 | piranhas
# Processing Record 10 of Set 11 | lakes entrance
# Processing Record 11 of Set 11 | gigmoto
# Processing Record 12 of Set 11 | rahuri
# Processing Record 13 of Set 11 | mazamari
# Processing Record 14 of Set 11 | mayo
# Processing Record 15 of Set 11 | warmbad
# Processing Record 16 of Set 11 | weinan
# Processing Record 17 of Set 11 | northam
# Processing Record 18 of Set 11 | dingle
# Processing Record 19 of Set 11 | kysyl-syr
# Processing Record 20 of Set 11 | bargal
# City not found. Skipping...
# Processing Record 21 of Set 11 | sangar
# Processing Record 22 of Set 11 | sao filipe
# Processing Record 23 of Set 11 | conceicao do araguaia
# Processing Record 24 of Set 11 | mattru
# Processing Record 25 of Set 11 | hyeres
# Processing Record 26 of Set 11 | sandwick
# Processing Record 27 of Set 11 | guerrero negro
# Processing Record 28 of Set 11 | soe
# Processing Record 29 of Set 11 | dicabisagan
# Processing Record 30 of Set 11 | barbacoas
# Processing Record 31 of Set 11 | sokoni
# Processing Record 32 of Set 11 | bubaque
# Processing Record 33 of Set 11 | zhaotong
# Processing Record 34 of Set 11 | imbituba
# Processing Record 35 of Set 11 | bom sucesso
# Processing Record 36 of Set 11 | solnechnyy
# Processing Record 37 of Set 11 | houma
# Processing Record 38 of Set 11 | miri
# Processing Record 39 of Set 11 | souillac
# Processing Record 40 of Set 11 | el banco
# Processing Record 41 of Set 11 | praia da vitoria
# Processing Record 42 of Set 11 | maniitsoq
# Processing Record 43 of Set 11 | senanga
# Processing Record 44 of Set 11 | ust-maya
# Processing Record 45 of Set 11 | nova vicosa
# Processing Record 46 of Set 11 | el tigre
# Processing Record 47 of Set 11 | lircay
# Processing Record 48 of Set 11 | sur
# Processing Record 49 of Set 11 | brae
# Processing Record 50 of Set 11 | patos
# Processing Record 1 of Set 12 | pavlogradka
# Processing Record 2 of Set 12 | gawler
# Processing Record 3 of Set 12 | baruun-urt
# Processing Record 4 of Set 12 | namatanai
# Processing Record 5 of Set 12 | manicore
# Processing Record 6 of Set 12 | tulsipur
# Processing Record 7 of Set 12 | calvinia
# Processing Record 8 of Set 12 | phumi samraong
# City not found. Skipping...
# Processing Record 9 of Set 12 | portree
# Processing Record 10 of Set 12 | ondorhaan
# City not found. Skipping...
# Processing Record 11 of Set 12 | tual
# Processing Record 12 of Set 12 | marystown
# Processing Record 13 of Set 12 | izhma
# Processing Record 14 of Set 12 | pisco
# Processing Record 15 of Set 12 | vanimo
# Processing Record 16 of Set 12 | selkirk
# Processing Record 17 of Set 12 | beringovskiy
# Processing Record 18 of Set 12 | belen
# Processing Record 19 of Set 12 | kutum
# Processing Record 20 of Set 12 | bhimunipatnam
# Processing Record 21 of Set 12 | kondinskoye
# Processing Record 22 of Set 12 | elizabeth city
# Processing Record 23 of Set 12 | svetlaya
# Processing Record 24 of Set 12 | alyangula
# Processing Record 25 of Set 12 | ukiah
# Processing Record 26 of Set 12 | bairiki
# Processing Record 27 of Set 12 | kattivakkam
# Processing Record 28 of Set 12 | chapais
# Processing Record 29 of Set 12 | cumaribo
# City not found. Skipping...
# Processing Record 30 of Set 12 | tsabong
# Processing Record 31 of Set 12 | arman
# Processing Record 32 of Set 12 | nome
# Processing Record 33 of Set 12 | riverdale
# Processing Record 34 of Set 12 | la reforma
# Processing Record 35 of Set 12 | storm lake
# Processing Record 36 of Set 12 | chiang kham
# Processing Record 37 of Set 12 | katobu
# Processing Record 38 of Set 12 | antofagasta
# Processing Record 39 of Set 12 | buala
# Processing Record 40 of Set 12 | manavgat
# Processing Record 41 of Set 12 | gympie
# Processing Record 42 of Set 12 | kralendijk
# Processing Record 43 of Set 12 | formosa do rio preto
# Processing Record 44 of Set 12 | havre-saint-pierre
# Processing Record 45 of Set 12 | huaiyuan
# Processing Record 46 of Set 12 | kamloops
# Processing Record 47 of Set 12 | artyk
# City not found. Skipping...
# Processing Record 48 of Set 12 | napier
# Processing Record 49 of Set 12 | lajas
# Processing Record 50 of Set 12 | rawannawi
# City not found. Skipping...
# Processing Record 1 of Set 13 | bella union
# Processing Record 2 of Set 13 | atar
# Processing Record 3 of Set 13 | mingyue
# Processing Record 4 of Set 13 | champerico
# Processing Record 5 of Set 13 | mayna
# Processing Record 6 of Set 13 | los algarrobos
# Processing Record 7 of Set 13 | lohja
# Processing Record 8 of Set 13 | san lawrenz
# Processing Record 9 of Set 13 | wajir
# Processing Record 10 of Set 13 | kununurra
# Processing Record 11 of Set 13 | kawalu
# Processing Record 12 of Set 13 | iquitos
# Processing Record 13 of Set 13 | thai binh
# Processing Record 14 of Set 13 | monrovia
# Processing Record 15 of Set 13 | sawakin
# Processing Record 16 of Set 13 | itaueira
# Processing Record 17 of Set 13 | the valley
# Processing Record 18 of Set 13 | izumo
# Processing Record 19 of Set 13 | razole
# Processing Record 20 of Set 13 | filadelfia
# Processing Record 21 of Set 13 | mackenzie
# Processing Record 22 of Set 13 | greenwood
# Processing Record 23 of Set 13 | balkanabat
# Processing Record 24 of Set 13 | gizo
# Processing Record 25 of Set 13 | cuamba
# Processing Record 26 of Set 13 | libres
# Processing Record 27 of Set 13 | qasigiannguit
# Processing Record 28 of Set 13 | norilsk
# Processing Record 29 of Set 13 | ville-marie
# Processing Record 30 of Set 13 | barcelos
# Processing Record 31 of Set 13 | yar-sale
# Processing Record 32 of Set 13 | karamea
# City not found. Skipping...
# Processing Record 33 of Set 13 | muhos
# Processing Record 34 of Set 13 | waingapu
# Processing Record 35 of Set 13 | yanam
# Processing Record 36 of Set 13 | kargasok
# Processing Record 37 of Set 13 | novaya malykla
# Processing Record 38 of Set 13 | maumere
# Processing Record 39 of Set 13 | halalo
# City not found. Skipping...
# Processing Record 40 of Set 13 | awbari
# Processing Record 41 of Set 13 | havoysund
# Processing Record 42 of Set 13 | weihe
# Processing Record 43 of Set 13 | waddan
# Processing Record 44 of Set 13 | bira
# Processing Record 45 of Set 13 | rzeszow
# Processing Record 46 of Set 13 | hvammstangi
# City not found. Skipping...
# Processing Record 47 of Set 13 | pacifica
# Processing Record 48 of Set 13 | aksarayskiy
# Processing Record 49 of Set 13 | huron
# Processing Record 50 of Set 13 | comodoro rivadavia
# Processing Record 1 of Set 14 | darab
# Processing Record 2 of Set 14 | rosarito
# Processing Record 3 of Set 14 | higuey
# City not found. Skipping...
# Processing Record 4 of Set 14 | suez
# Processing Record 5 of Set 14 | ulladulla
# Processing Record 6 of Set 14 | miass
# Processing Record 7 of Set 14 | saquarema
# Processing Record 8 of Set 14 | wer
# Processing Record 9 of Set 14 | amderma
# City not found. Skipping...
# Processing Record 10 of Set 14 | westport
# Processing Record 11 of Set 14 | nemuro
# Processing Record 12 of Set 14 | kletnya
# Processing Record 13 of Set 14 | karachi
# Processing Record 14 of Set 14 | saint-pierre
# Processing Record 15 of Set 14 | chernushka
# Processing Record 16 of Set 14 | iseyin
# Processing Record 17 of Set 14 | kazalinsk
# City not found. Skipping...
# Processing Record 18 of Set 14 | daru
# Processing Record 19 of Set 14 | jalu
# Processing Record 20 of Set 14 | pangnirtung
# Processing Record 21 of Set 14 | mahajanga
# Processing Record 22 of Set 14 | tura
# Processing Record 23 of Set 14 | bundi
# Processing Record 24 of Set 14 | lumeje
# Processing Record 25 of Set 14 | szigetvar
# Processing Record 26 of Set 14 | azul
# Processing Record 27 of Set 14 | orlik
# Processing Record 28 of Set 14 | myski
# Processing Record 29 of Set 14 | illapel
# Processing Record 30 of Set 14 | hamilton
# Processing Record 31 of Set 14 | manavalakurichi
# Processing Record 32 of Set 14 | alihe
# Processing Record 33 of Set 14 | aljezur
# Processing Record 34 of Set 14 | vaitupu
# City not found. Skipping...
# Processing Record 35 of Set 14 | sorong
# Processing Record 36 of Set 14 | marsassoum
# Processing Record 37 of Set 14 | kupang
# Processing Record 38 of Set 14 | ormara
# Processing Record 39 of Set 14 | havelock
# Processing Record 40 of Set 14 | saint-leu
# Processing Record 41 of Set 14 | harlingen
# Processing Record 42 of Set 14 | jaque
# Processing Record 43 of Set 14 | polyarnyy
# Processing Record 44 of Set 14 | ochtrup
# Processing Record 45 of Set 14 | chicama
# Processing Record 46 of Set 14 | misratah
# Processing Record 47 of Set 14 | rungata
# City not found. Skipping...
# Processing Record 48 of Set 14 | lago da pedra
# Processing Record 49 of Set 14 | mogwase
# Processing Record 50 of Set 14 | rio gallegos
# Processing Record 1 of Set 15 | erdenet
# Processing Record 2 of Set 15 | secovce
# Processing Record 3 of Set 15 | mweka
# Processing Record 4 of Set 15 | kadykchan
# City not found. Skipping...
# Processing Record 5 of Set 15 | kaberamaido
# Processing Record 6 of Set 15 | dunedin
# Processing Record 7 of Set 15 | camacha
# Processing Record 8 of Set 15 | mossoro
# Processing Record 9 of Set 15 | quatre cocos
# Processing Record 10 of Set 15 | ada
# Processing Record 11 of Set 15 | zapolyarnyy
# Processing Record 12 of Set 15 | kuito
# Processing Record 13 of Set 15 | makakilo city
# Processing Record 14 of Set 15 | bambous virieux
# Processing Record 15 of Set 15 | la macarena
# Processing Record 16 of Set 15 | pastos bons
# Processing Record 17 of Set 15 | cavaillon
# Processing Record 18 of Set 15 | hihifo
# City not found. Skipping...
# Processing Record 19 of Set 15 | itarema
# Processing Record 20 of Set 15 | la arena
# Processing Record 21 of Set 15 | sorland
# Processing Record 22 of Set 15 | hendijan
# City not found. Skipping...
# Processing Record 23 of Set 15 | muslyumovo
# Processing Record 24 of Set 15 | kingston
# Processing Record 25 of Set 15 | barra do bugres
# Processing Record 26 of Set 15 | ensenada
# Processing Record 27 of Set 15 | gadsden
# Processing Record 28 of Set 15 | la rioja
# Processing Record 29 of Set 15 | loukhi
# Processing Record 30 of Set 15 | macas
# Processing Record 31 of Set 15 | lubumbashi
# Processing Record 32 of Set 15 | lere
# Processing Record 33 of Set 15 | kelvington
# Processing Record 34 of Set 15 | barroualie
# City not found. Skipping...
# Processing Record 35 of Set 15 | tainan
# Processing Record 36 of Set 15 | kloulklubed
# Processing Record 37 of Set 15 | flinders
# Processing Record 38 of Set 15 | manzil tamim
# City not found. Skipping...
# Processing Record 39 of Set 15 | uarini
# Processing Record 40 of Set 15 | tahoua
# Processing Record 41 of Set 15 | rorvik
# Processing Record 42 of Set 15 | mocambique
# City not found. Skipping...
# Processing Record 43 of Set 15 | urfa
# City not found. Skipping...
# Processing Record 44 of Set 15 | kwinana
# Processing Record 45 of Set 15 | ahipara
# Processing Record 46 of Set 15 | port hardy
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(2)
# Out:
#       City      Lat       Lng  Max_Temp  Humidity  Cloudiness  Wind Speed  \
# 0  Bontang   0.1333  117.5000    76.568        90         100        4.22
# 1    Bluff -46.6000  168.3333    51.728        75          78        7.48
#
#   Current_Description Country                 Date
# 0       moderate rain      ID  2021-11-28 17:12:16
# 1       broken clouds      NZ  2021-11-28 17:12:16

# %%
# Create the output file (CSV).
output_data_file = "C:/Users/ryanj/github/World_Weather_Analysis/weather_database/weatherpy_database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
